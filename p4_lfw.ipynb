# %% [markdown]
# # Common

# %% [markdown]
# **EXECUTION ENVIRONMENT MUST BE "GPU"**

# %%
import os
import numpy as np
from sklearn import neighbors as knn
from glob import glob
from tqdm.notebook import tqdm
import cv2
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
from sklearn.metrics import balanced_accuracy_score
import itertools
import dlib
from sklearn.model_selection import GridSearchCV
import pandas as pd
from joblib import parallel_backend

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = '/content/drive/MyDrive/dl_for_cv/data/lfw'
# %cd '/content/drive/MyDrive/'
# %mkdir -p 'dl_for_cv/data/lfw'
# Out:
# /content/drive/MyDrive
# /dlw_for_cv/data/lfw

# %% [markdown]
# # Labeled Faces in the Wild

# %% [markdown]
# Labeled Faces in the Wild is a database of face photographs designed for studying the problem of unconstrained face recognition. The data set contains more than 13,000 images of faces collected from the web. Each face has been labeled with the name of the person pictured. 1680 of the people pictured have two or more distinct photos in the data set. See [homepage](http://vis-www.cs.umass.edu/lfw/).

# %%
# %cd '/content/drive/MyDrive/dl_for_cv/data/'
# Out:
# /content/drive/MyDrive/dl_for_cv/data

# %%
# !wget -O lfw.tgz https://figshare.com/ndownloader/files/5976018
# Out:
# --2025-05-10 07:46:00--  https://figshare.com/ndownloader/files/5976018
# Resolving figshare.com (figshare.com)... 52.48.143.184, 54.216.15.6, 34.255.146.38, ...
# Connecting to figshare.com (figshare.com)|52.48.143.184|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/5976018/lfw.tgz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250510/eu-west-1/s3/aws4_request&X-Amz-Date=20250510T074600Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=0fbaa12100da70f33da94879c08f746666cd21ee3fcd96a4f3deda58878149ab [following]
# --2025-05-10 07:46:00--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/5976018/lfw.tgz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20250510/eu-west-1/s3/aws4_request&X-Amz-Date=20250510T074600Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=0fbaa12100da70f33da94879c08f746666cd21ee3fcd96a4f3deda58878149ab
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.92.17.96, 3.5.64.193, 52.218.41.195, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.92.17.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 180566744 (172M) [binary/octet-stream]
# Saving to: ‘5976018’
#
# 5976018             100%[===================>] 172.20M  30.4MB/s    in 6.5s
#
# 2025-05-10 07:46:07 (26.4 MB/s) - ‘5976018’ saved [180566744/180566744]

# %%
# !tar -xzf lfw.tgz

# %% [markdown]
# # Dataset preparation

# %%
DATA_DIR = '/content/drive/MyDrive/dl_for_cv/data/lfw'
DB_RATIO = 0.2

# %%
persons = []
person_qs = []

for person in sorted(os.listdir(DATA_DIR)):
    persons.append(person)
    person_qs.append(len(glob(os.path.join(DATA_DIR, person, '*.jpg'))))

persons = np.asarray(persons)
person_qs = np.asarray(person_qs)

print(persons.size, person_qs.size)
# Out:
# 5749 5749

# %%
plt.figure(figsize=(15, 5))
plt.hist(person_qs, bins=1000)
plt.stem([2], [4000], 'r')
plt.grid(True)

plt.xlim(0, 40)
# Out:
# (0.0, 40.0)

# %%
person_qs[person_qs > 2].sum() / person_qs.sum()
# Out:
# np.float64(0.5747751832539862)

# %%
persons_known = persons[person_qs > 2]
persons_unkonwn = persons[person_qs <= 2]

print(persons_known.size, persons_unkonwn.size, persons_known.size + persons_unkonwn.size)
# Out:
# 901 4848 5749

# %%
person_to_id = {}
for p_id, person in enumerate(sorted(persons_known)):
    person_to_id[person] = p_id

# %%
person_to_id
# Out:
# {np.str_('Aaron_Peirsol'): 0,
#  np.str_('Abdoulaye_Wade'): 1,
#  np.str_('Abdullah'): 2,
#  np.str_('Abdullah_Gul'): 3,
#  np.str_('Abdullah_al-Attiyah'): 4,
#  np.str_('Abel_Pacheco'): 5,
#  np.str_('Abid_Hamid_Mahmud_Al-Tikriti'): 6,
#  np.str_('Adam_Sandler'): 7,
#  np.str_('Adel_Al-Jubeir'): 8,
#  np.str_('Adolfo_Aguilar_Zinser'): 9,
#  np.str_('Adrien_Brody'): 10,
#  np.str_('Ahmed_Chalabi'): 11,
#  np.str_('Ai_Sugiyama'): 12,
#  np.str_('Aicha_El_Ouafi'): 13,
#  np.str_('Akbar_Hashemi_Rafsanjani'): 14,
#  np.str_('Akhmed_Zakayev'): 15,
#  np.str_('Al_Gore'): 16,
#  np.str_('Al_Pacino'): 17,
#  np.str_('Al_Sharpton'): 18,
#  np.str_('Alan_Greenspan'): 19,
#  np.str_('Alastair_Campbell'): 20,
#  np.str_('Albert_Costa'): 21,
#  np.str_('Alec_Baldwin'): 22,
#  np.str_('Alejandro_Avila'): 23,
#  np.str_('Alejandro_Toledo'): 24,
#  np.str_('Aleksander_Kwasniewski'): 25,
#  np.str_('Alex_Sink'): 26,
#  np.str_('Alexander_Downer'): 27,
#  np.str_('Alexander_Losyukov'): 28,
#  np.str_('Alexandra_Stevenson'): 29,
#  np.str_('Ali_Khamenei'): 30,
#  np.str_('Ali_Naimi'): 31,
#  np.str_('Allyson_Felix'): 32,
#  np.str_('Alvaro_Noboa'): 33,
#  np.str_('Alvaro_Silva_Calderon'): 34,
#  np.str_('Alvaro_Uribe'): 35,
#  np.str_('Amanda_Bynes'): 36,
#  np.str_('Amelia_Vega'): 37,
#  np.str_('Amelie_Mauresmo'): 38,
#  np.str_('Amer_al-Saadi'): 39,
#  np.str_('Ana_Guevara'): 40,
#  np.str_('Ana_Palacio'): 41,
#  np.str_('Anastasia_Myskina'): 42,
#  np.str_('Anders_Ebbeson'): 43,
#  np.str_('Anders_Fogh_Rasmussen'): 44,
#  np.str_('Andre_Agassi'): 45,
#  np.str_('Andrew_Weissmann'): 46,
#  np.str_('Andy_Roddick'): 47,
#  np.str_('Angela_Bassett'): 48,
#  np.str_('Angela_Merkel'): 49,
#  np.str_('Angelina_Jolie'): 50,
#  np.str_('Angelo_Reyes'): 51,
#  np.str_('Anibal_Ibarra'): 52,
#  np.str_('Ann_Veneman'): 53,
#  np.str_('Anna_Kournikova'): 54,
#  np.str_('Anne_Krueger'): 55,
#  np.str_('Anne_McLellan'): 56,
#  np.str_('Annette_Lu'): 57,
#  np.str_('Antonio_Banderas'): 58,
#  np.str_('Antonio_Palocci'): 59,
#  np.str_('Antonio_Trillanes'): 60,
#  np.str_('Antony_Leung'): 61,
#  np.str_('Ari_Fleischer'): 62,
#  np.str_('Arianna_Huffington'): 63,
#  np.str_('Ariel_Sharon'): 64,
#  np.str_('Arlen_Specter'): 65,
#  np.str_('Arminio_Fraga'): 66,
#  np.str_('Arnold_Palmer'): 67,
#  np.str_('Arnold_Schwarzenegger'): 68,
#  np.str_('Arnoldo_Aleman'): 69,
#  np.str_('Art_Howe'): 70,
#  np.str_('Arturo_Gatti'): 71,
#  np.str_('Ashanti'): 72,
#  np.str_('Ashton_Kutcher'): 73,
#  np.str_('Atal_Bihari_Vajpayee'): 74,
#  np.str_('Augustin_Calleri'): 75,
#  np.str_('Azra_Akin'): 76,
#  np.str_('Barbara_Walters'): 77,
#  np.str_('Barbra_Streisand'): 78,
#  np.str_('Bashar_Assad'): 79,
#  np.str_('Ben_Affleck'): 80,
#  np.str_('Ben_Curtis'): 81,
#  np.str_('Ben_Howland'): 82,
#  np.str_('Benazir_Bhutto'): 83,
#  np.str_('Benjamin_Netanyahu'): 84,
#  np.str_('Bernard_Landry'): 85,
#  np.str_('Bernard_Law'): 86,
#  np.str_('Bertie_Ahern'): 87,
#  np.str_('Bijan_Darvish'): 88,
#  np.str_('Biljana_Plavsic'): 89,
#  np.str_('Bill_Callahan'): 90,
#  np.str_('Bill_Clinton'): 91,
#  np.str_('Bill_Frist'): 92,
#  np.str_('Bill_Gates'): 93,
#  np.str_('Bill_Graham'): 94,
#  np.str_('Bill_McBride'): 95,
#  np.str_('Bill_Paxton'): 96,
#  np.str_('Bill_Simon'): 97,
#  np.str_('Billy_Crystal'): 98,
#  np.str_('Binyamin_Ben-Eliezer'): 99,
#  np.str_('Bob_Dole'): 100,
#  np.str_('Bob_Graham'): 101,
#  np.str_('Bob_Hope'): 102,
#  np.str_('Bob_Huggins'): 103,
#  np.str_('Bob_Stoops'): 104,
#  np.str_('Bono'): 105,
#  np.str_('Boris_Becker'): 106,
#  np.str_('Brad_Garrett'): 107,
#  np.str_('Brad_Johnson'): 108,
#  np.str_('Branko_Crvenkovski'): 109,
#  np.str_('Bridget_Fonda'): 110,
#  np.str_('Bridgette_Wilson-Sampras'): 111,
#  np.str_('Britney_Spears'): 112,
#  np.str_('Bruce_Springsteen'): 113,
#  np.str_('Bud_Selig'): 114,
#  np.str_('Bulent_Ecevit'): 115,
#  np.str_('Calista_Flockhart'): 116,
#  np.str_('Cameron_Diaz'): 117,
#  np.str_('Candice_Bergen'): 118,
#  np.str_('Candie_Kung'): 119,
#  np.str_('Carla_Del_Ponte'): 120,
#  np.str_('Carlo_Ancelotti'): 121,
#  np.str_('Carlos_Manuel_Pruneda'): 122,
#  np.str_('Carlos_Menem'): 123,
#  np.str_('Carlos_Moya'): 124,
#  np.str_('Carlos_Ortega'): 125,
#  np.str_('Carlos_Ruiz'): 126,
#  np.str_('Carlos_Vives'): 127,
#  np.str_('Carly_Fiorina'): 128,
#  np.str_('Carmen_Electra'): 129,
#  np.str_('Carolina_Kluft'): 130,
#  np.str_('Caroline_Kennedy'): 131,
#  np.str_('Carolyn_Dawn_Johnson'): 132,
#  np.str_('Carrie-Anne_Moss'): 133,
#  np.str_('Carson_Palmer'): 134,
#  np.str_('Cate_Blanchett'): 135,
#  np.str_('Catherine_Deneuve'): 136,
#  np.str_('Catherine_Zeta-Jones'): 137,
#  np.str_('Cecilia_Bolocco'): 138,
#  np.str_('Celine_Dion'): 139,
#  np.str_('Cesar_Gaviria'): 140,
#  np.str_('Chan_Gailey'): 141,
#  np.str_('Chanda_Rubin'): 142,
#  np.str_('Charles_Bronson'): 143,
#  np.str_('Charles_Moose'): 144,
#  np.str_('Charles_Taylor'): 145,
#  np.str_('Charlton_Heston'): 146,
#  np.str_('Chen_Shui-bian'): 147,
#  np.str_('Cherie_Blair'): 148,
#  np.str_('Chick_Hearn'): 149,
#  np.str_('Choi_Sung-hong'): 150,
#  np.str_('Christian_Longo'): 151,
#  np.str_('Christina_Aguilera'): 152,
#  np.str_('Christine_Baumgartner'): 153,
#  np.str_('Christine_Gregoire'): 154,
#  np.str_('Christine_Todd_Whitman'): 155,
#  np.str_('Christopher_Reeve'): 156,
#  np.str_('Christopher_Walken'): 157,
#  np.str_('Cindy_Crawford'): 158,
#  np.str_('Ciro_Gomes'): 159,
#  np.str_('Claire_Danes'): 160,
#  np.str_('Clara_Harris'): 161,
#  np.str_('Clare_Short'): 162,
#  np.str_('Claudia_Pechstein'): 163,
#  np.str_('Claudia_Schiffer'): 164,
#  np.str_('Clay_Aiken'): 165,
#  np.str_('Clint_Eastwood'): 166,
#  np.str_('Colin_Farrell'): 167,
#  np.str_('Colin_Montgomerie'): 168,
#  np.str_('Colin_Powell'): 169,
#  np.str_('Conan_OBrien'): 170,
#  np.str_('Conchita_Martinez'): 171,
#  np.str_('Condoleezza_Rice'): 172,
#  np.str_('Constance_Marie'): 173,
#  np.str_('Coretta_Scott_King'): 174,
#  np.str_('Costas_Simitis'): 175,
#  np.str_('Cruz_Bustamante'): 176,
#  np.str_('Daisy_Fuentes'): 177,
#  np.str_('Dale_Earnhardt_Jr'): 178,
#  np.str_('Dan_Morales'): 179,
#  np.str_('Daniel_Day-Lewis'): 180,
#  np.str_('Daniel_Radcliffe'): 181,
#  np.str_('Dave_Campo'): 182,
#  np.str_('David_Anderson'): 183,
#  np.str_('David_Beckham'): 184,
#  np.str_('David_Caruso'): 185,
#  np.str_('David_Heymann'): 186,
#  np.str_('David_Hyde_Pierce'): 187,
#  np.str_('David_Nalbandian'): 188,
#  np.str_('David_Stern'): 189,
#  np.str_('David_Trimble'): 190,
#  np.str_('David_Wells'): 191,
#  np.str_('Dean_Barkley'): 192,
#  np.str_('Debbie_Reynolds'): 193,
#  np.str_('Debra_Messing'): 194,
#  np.str_('Demi_Moore'): 195,
#  np.str_('Dennis_Hastert'): 196,
#  np.str_('Dennis_Kucinich'): 197,
#  np.str_('Denzel_Washington'): 198,
#  np.str_('Derek_Jeter'): 199,
#  np.str_('Diana_Krall'): 200,
#  np.str_('Diana_Munz'): 201,
#  np.str_('Dianne_Feinstein'): 202,
#  np.str_('Dick_Cheney'): 203,
#  np.str_('Dick_Clark'): 204,
#  np.str_('Dominique_de_Villepin'): 205,
#  np.str_('Don_Siegelman'): 206,
#  np.str_('Donald_Fehr'): 207,
#  np.str_('Donald_Pettit'): 208,
#  np.str_('Donald_Rumsfeld'): 209,
#  np.str_('Donatella_Versace'): 210,
#  np.str_('Doris_Roberts'): 211,
#  np.str_('Doris_Schroeder'): 212,
#  np.str_('Doug_Melvin'): 213,
#  np.str_('Ed_Rosenthal'): 214,
#  np.str_('Ed_Smart'): 215,
#  np.str_('Edmund_Hillary'): 216,
#  np.str_('Edmund_Stoiber'): 217,
#  np.str_('Eduard_Shevardnadze'): 218,
#  np.str_('Eduardo_Duhalde'): 219,
#  np.str_('Edward_Kennedy'): 220,
#  np.str_('Edward_Lu'): 221,
#  np.str_('Edwin_Edwards'): 222,
#  np.str_('Edwina_Currie'): 223,
#  np.str_('Eileen_Coparropa'): 224,
#  np.str_('Elena_Bovina'): 225,
#  np.str_('Eliane_Karp'): 226,
#  np.str_('Elijah_Wood'): 227,
#  np.str_('Elizabeth_Dole'): 228,
#  np.str_('Elizabeth_Hurley'): 229,
#  np.str_('Elizabeth_Smart'): 230,
#  np.str_('Elsa_Zylberstein'): 231,
#  np.str_('Elton_John'): 232,
#  np.str_('Emanuel_Ginobili'): 233,
#  np.str_('Emma_Thompson'): 234,
#  np.str_('Emma_Watson'): 235,
#  np.str_('Emmanuelle_Beart'): 236,
#  np.str_('Enrique_Bolanos'): 237,
#  np.str_('Eric_Robert_Rudolph'): 238,
#  np.str_('Erik_Morales'): 239,
#  np.str_('Erika_Harold'): 240,
#  np.str_('Erin_Runnion'): 241,
#  np.str_('Ernie_Els'): 242,
#  np.str_('Ethan_Hawke'): 243,
#  np.str_('Evan_Rachel_Wood'): 244,
#  np.str_('Fabrice_Santoro'): 245,
#  np.str_('Farouk_al-Sharaa'): 246,
#  np.str_('Faye_Dunaway'): 247,
#  np.str_('Fayssal_Mekdad'): 248,
#  np.str_('Federico_Trillo'): 249,
#  np.str_('Felipe_Perez_Roque'): 250,
#  np.str_('Fernando_Gonzalez'): 251,
#  np.str_('Fernando_Henrique_Cardoso'): 252,
#  np.str_('Fernando_Vargas'): 253,
#  np.str_('Fidel_Castro'): 254,
#  np.str_('Filippo_Inzaghi'): 255,
#  np.str_('Francisco_Flores'): 256,
#  np.str_('Frank_Cassell'): 257,
#  np.str_('Frank_Solich'): 258,
#  np.str_('Franz_Fischler'): 259,
#  np.str_('Franz_Muentefering'): 260,
#  np.str_('Fred_Eckhard'): 261,
#  np.str_('Fred_Thompson'): 262,
#  np.str_('Fujio_Cho'): 263,
#  np.str_('GL_Peiris'): 264,
#  np.str_('Gary_Carter'): 265,
#  np.str_('Gary_Doer'): 266,
#  np.str_('Gene_Robinson'): 267,
#  np.str_('Geoff_Hoon'): 268,
#  np.str_('George_Clooney'): 269,
#  np.str_('George_Galloway'): 270,
#  np.str_('George_HW_Bush'): 271,
#  np.str_('George_Lopez'): 272,
#  np.str_('George_Papandreou'): 273,
#  np.str_('George_Pataki'): 274,
#  np.str_('George_Robertson'): 275,
#  np.str_('George_Ryan'): 276,
#  np.str_('George_Voinovich'): 277,
#  np.str_('George_W_Bush'): 278,
#  np.str_('Geraldine_Chaplin'): 279,
#  np.str_('Gerhard_Schroeder'): 280,
#  np.str_('Gerry_Adams'): 281,
#  np.str_('Gian_Marco'): 282,
#  np.str_('Gianna_Angelopoulos-Daskalaki'): 283,
#  np.str_('Gil_de_Ferran'): 284,
#  np.str_('Gilberto_Rodriguez_Orejuela'): 285,
#  np.str_('Giuseppe_Gibilisco'): 286,
#  np.str_('Glafcos_Clerides'): 287,
#  np.str_('Gloria_Macapagal_Arroyo'): 288,
#  np.str_('Gloria_Trevi'): 289,
#  np.str_('Goldie_Hawn'): 290,
#  np.str_('Gonzalo_Sanchez_de_Lozada'): 291,
#  np.str_('Gordon_Brown'): 292,
#  np.str_('Grant_Hackett'): 293,
#  np.str_('Gray_Davis'): 294,
#  np.str_('Greg_Rusedski'): 295,
#  np.str_('Gregg_Popovich'): 296,
#  np.str_('Guillermo_Canas'): 297,
#  np.str_('Guillermo_Coria'): 298,
#  np.str_('Gunter_Pleuger'): 299,
#  np.str_('Gus_Van_Sant'): 300,
#  np.str_('Gustavo_Kuerten'): 301,
#  np.str_('Gwendal_Peizerat'): 302,
#  np.str_('Gwyneth_Paltrow'): 303,
#  np.str_('Habib_Rizieq'): 304,
#  np.str_('Hal_Gehman'): 305,
#  np.str_('Halle_Berry'): 306,
#  np.str_('Hamid_Karzai'): 307,
#  np.str_('Hans_Blix'): 308,
#  np.str_('Hans_Eichel'): 309,
#  np.str_('Harrison_Ford'): 310,
#  np.str_('Harry_Schmidt'): 311,
#  np.str_('Heath_Ledger'): 312,
#  np.str_('Heather_Mills'): 313,
#  np.str_('Hector_Babenco'): 314,
#  np.str_('Hee-Won_Han'): 315,
#  np.str_('Heidi_Fleiss'): 316,
#  np.str_('Heidi_Klum'): 317,
#  np.str_('Heinz_Feldmann'): 318,
#  np.str_('Heizo_Takenaka'): 319,
#  np.str_('Helen_Clark'): 320,
#  np.str_('Herb_Sendek'): 321,
#  np.str_('Hilary_Duff'): 322,
#  np.str_('Hillary_Clinton'): 323,
#  np.str_('Hipolito_Mejia'): 324,
#  np.str_('Hitomi_Soga'): 325,
#  np.str_('Holly_Hunter'): 326,
#  np.str_('Horst_Koehler'): 327,
#  np.str_('Hosni_Mubarak'): 328,
#  np.str_('Howard_Dean'): 329,
#  np.str_('Hu_Jintao'): 330,
#  np.str_('Hugh_Grant'): 331,
#  np.str_('Hugo_Chavez'): 332,
#  np.str_('Hun_Sen'): 333,
#  np.str_('Iain_Duncan_Smith'): 334,
#  np.str_('Ian_McKellen'): 335,
#  np.str_('Ian_Thorpe'): 336,
#  np.str_('Igor_Ivanov'): 337,
#  np.str_('Ilan_Ramon'): 338,
#  np.str_('Intisar_Ajouri'): 339,
#  np.str_('Isabella_Rossellini'): 340,
#  np.str_('JK_Rowling'): 341,
#  np.str_('Jack_Nicholson'): 342,
#  np.str_('Jack_Straw'): 343,
#  np.str_('Jackie_Chan'): 344,
#  np.str_('Jacques_Chirac'): 345,
#  np.str_('Jacques_Rogge'): 346,
#  np.str_('Jake_Gyllenhaal'): 347,
#  np.str_('James_Blake'): 348,
#  np.str_('James_Caan'): 349,
#  np.str_('James_Cameron'): 350,
#  np.str_('James_Cunningham'): 351,
#  np.str_('James_Gandolfini'): 352,
#  np.str_('James_Kelly'): 353,
#  np.str_('James_Kopp'): 354,
#  np.str_('James_McGreevey'): 355,
#  np.str_('James_Traficant'): 356,
#  np.str_('James_Wolfensohn'): 357,
#  np.str_('Jan-Michael_Gambill'): 358,
#  np.str_('Jan_Ullrich'): 359,
#  np.str_('Janet_Napolitano'): 360,
#  np.str_('Jason_Kidd'): 361,
#  np.str_('Javier_Solana'): 362,
#  np.str_('Javier_Weber'): 363,
#  np.str_('Jay_Garner'): 364,
#  np.str_('Jay_Leno'): 365,
#  np.str_('Jayson_Williams'): 366,
#  np.str_('Jean-David_Levitte'): 367,
#  np.str_('Jean-Francois_Pontal'): 368,
#  np.str_('Jean-Pierre_Raffarin'): 369,
#  np.str_('Jean_Charest'): 370,
#  np.str_('Jean_Chretien'): 371,
#  np.str_('Jeb_Bush'): 372,
#  np.str_('Jeff_Van_Gundy'): 373,
#  np.str_('Jelena_Dokic'): 374,
#  np.str_('Jennifer_Aniston'): 375,
#  np.str_('Jennifer_Capriati'): 376,
#  np.str_('Jennifer_Connelly'): 377,
#  np.str_('Jennifer_Garner'): 378,
#  np.str_('Jennifer_Keller'): 379,
#  np.str_('Jennifer_Lopez'): 380,
#  np.str_('Jeong_Se-hyun'): 381,
#  np.str_('Jeremy_Greenstock'): 382,
#  np.str_('Jerry_Regier'): 383,
#  np.str_('Jerry_Springer'): 384,
#  np.str_('Jesse_Harris'): 385,
#  np.str_('Jesse_Jackson'): 386,
#  np.str_('Jesse_Ventura'): 387,
#  np.str_('Jiang_Zemin'): 388,
#  np.str_('Jim_Carrey'): 389,
#  np.str_('Jim_Furyk'): 390,
#  np.str_('Jim_Hahn'): 391,
#  np.str_('Jim_OBrien'): 392,
#  np.str_('Jim_Tressel'): 393,
#  np.str_('Jimmy_Carter'): 394,
#  np.str_('Jiri_Novak'): 395,
#  np.str_('Joan_Laporta'): 396,
#  np.str_('Jodie_Foster'): 397,
#  np.str_('Joe_Lieberman'): 398,
#  np.str_('Joe_Nichols'): 399,
#  np.str_('Joe_Torre'): 400,
#  np.str_('John_Abizaid'): 401,
#  np.str_('John_Allen_Muhammad'): 402,
#  np.str_('John_Ashcroft'): 403,
#  np.str_('John_Bolton'): 404,
#  np.str_('John_Edwards'): 405,
#  np.str_('John_Howard'): 406,
#  np.str_('John_Kerry'): 407,
#  np.str_('John_Malkovich'): 408,
#  np.str_('John_Manley'): 409,
#  np.str_('John_Mayer'): 410,
#  np.str_('John_McCain'): 411,
#  np.str_('John_Negroponte'): 412,
#  np.str_('John_Paul_II'): 413,
#  np.str_('John_Reid'): 414,
#  np.str_('John_Rosa'): 415,
#  np.str_('John_Snow'): 416,
#  np.str_('John_Stockton'): 417,
#  np.str_('John_Swofford'): 418,
#  np.str_('John_Travolta'): 419,
#  np.str_('John_Warner'): 420,
#  np.str_('Johnny_Tapia'): 421,
#  np.str_('Jon_Corzine'): 422,
#  np.str_('Jon_Gruden'): 423,
#  np.str_('Jon_Voight'): 424,
#  np.str_('Jonathan_Edwards'): 425,
#  np.str_('Jong_Wook_Lee'): 426,
#  np.str_('Jorge_Batlle'): 427,
#  np.str_('Joschka_Fischer'): 428,
#  np.str_('Jose_Canseco'): 429,
#  np.str_('Jose_Manuel_Durao_Barroso'): 430,
#  np.str_('Jose_Maria_Aznar'): 431,
#  np.str_('Jose_Sarney'): 432,
#  np.str_('Jose_Serra'): 433,
#  np.str_('Joseph_Biden'): 434,
#  np.str_('Joseph_Deiss'): 435,
#  np.str_('Joseph_Estrada'): 436,
#  np.str_('Juan_Carlos_Ferrero'): 437,
#  np.str_('Juan_Ignacio_Chela'): 438,
#  np.str_('Juan_Manuel_Marquez'): 439,
#  np.str_('Juan_Pablo_Montoya'): 440,
#  np.str_('Juanes'): 441,
#  np.str_('Julia_Tymoshenko'): 442,
#  np.str_('Julianne_Moore'): 443,
#  np.str_('Julie_Gerberding'): 444,
#  np.str_('Junichiro_Koizumi'): 445,
#  np.str_('Justin_Guarini'): 446,
#  np.str_('Justin_Leonard'): 447,
#  np.str_('Justin_Timberlake'): 448,
#  np.str_('Justine_Henin'): 449,
#  np.str_('Justine_Pasek'): 450,
#  np.str_('Kalpana_Chawla'): 451,
#  np.str_('Kamal_Kharrazi'): 452,
#  np.str_('Kate_Hudson'): 453,
#  np.str_('Kate_Winslet'): 454,
#  np.str_('Katherine_Harris'): 455,
#  np.str_('Kathleen_Kennedy_Townsend'): 456,
#  np.str_('Katie_Harman'): 457,
#  np.str_('Keanu_Reeves'): 458,
#  np.str_('Keith_Bogans'): 459,
#  np.str_('Kelly_Clarkson'): 460,
#  np.str_('Kelvin_Sampson'): 461,
#  np.str_('Kemal_Dervis'): 462,
#  np.str_('Ken_Macha'): 463,
#  np.str_('Kenneth_Bowersox'): 464,
#  np.str_('Kevin_Costner'): 465,
#  np.str_('Kevin_Spacey'): 466,
#  np.str_('Kim_Clijsters'): 467,
#  np.str_('Kim_Dae-jung'): 468,
#  np.str_('Kim_Jong-Il'): 469,
#  np.str_('Kim_Ryong-sung'): 470,
#  np.str_('Kim_Yong-il'): 471,
#  np.str_('Kimi_Raikkonen'): 472,
#  np.str_('King_Abdullah_II'): 473,
#  np.str_('Kirk_Johnson'): 474,
#  np.str_('Kjell_Magne_Bondevik'): 475,
#  np.str_('Kobe_Bryant'): 476,
#  np.str_('Kofi_Annan'): 477,
#  np.str_('Kristanna_Loken'): 478,
#  np.str_('Kristen_Breitweiser'): 479,
#  np.str_('Kristin_Davis'): 480,
#  np.str_('Kurt_Warner'): 481,
#  np.str_('Kwon_Yang-sook'): 482,
#  np.str_('LK_Advani'): 483,
#  np.str_('Laila_Ali'): 484,
#  np.str_('Lance_Armstrong'): 485,
#  np.str_('Lance_Bass'): 486,
#  np.str_('Larry_Brown'): 487,
#  np.str_('Larry_Coker'): 488,
#  np.str_('Larry_Ellison'): 489,
#  np.str_('Larry_Thompson'): 490,
#  np.str_('Lars_Von_Trier'): 491,
#  np.str_('Laura_Bush'): 492,
#  np.str_('Laura_Linney'): 493,
#  np.str_('LeBron_James'): 494,
#  np.str_('Lee_Hoi-chang'): 495,
#  np.str_('Lee_Soo-hyuck'): 496,
#  np.str_('Lennox_Lewis'): 497,
#  np.str_('Lenny_Wilkens'): 498,
#  np.str_('Leonardo_DiCaprio'): 499,
#  np.str_('Leonid_Kuchma'): 500,
#  np.str_('Lesley_McCulloch'): 501,
#  np.str_('Leslie_Caldwell'): 502,
#  np.str_('Leszek_Miller'): 503,
#  np.str_('Li_Peng'): 504,
#  np.str_('Li_Zhaoxing'): 505,
#  np.str_('Liam_Neeson'): 506,
#  np.str_('Lindsay_Davenport'): 507,
#  np.str_('Lino_Oviedo'): 508,
#  np.str_('Lisa_Marie_Presley'): 509,
#  np.str_('Liza_Minnelli'): 510,
#  np.str_('Lleyton_Hewitt'): 511,
#  np.str_('Lou_Piniella'): 512,
#  np.str_('Luciano_Pavarotti'): 513,
#  np.str_('Lucio_Gutierrez'): 514,
#  np.str_('Lucy_Liu'): 515,
#  np.str_('Ludivine_Sagnier'): 516,
#  np.str_('Luis_Ernesto_Derbez_Bautista'): 517,
#  np.str_('Luis_Figo'): 518,
#  np.str_('Luis_Gonzalez_Macchi'): 519,
#  np.str_('Luis_Horna'): 520,
#  np.str_('Luiz_Inacio_Lula_da_Silva'): 521,
#  np.str_('Lynn_Redgrave'): 522,
#  np.str_('Lynne_Cheney'): 523,
#  np.str_('Madeleine_Albright'): 524,
#  np.str_('Madonna'): 525,
#  np.str_('Magdalena_Maleeva'): 526,
#  np.str_('Mahathir_Mohamad'): 527,
#  np.str_('Mahmoud_Abbas'): 528,
#  np.str_('Makhdoom_Amin_Fahim'): 529,
#  np.str_('Marat_Safin'): 530,
#  np.str_('Marc_Grossman'): 531,
#  np.str_('Marcelo_Ebrard'): 532,
#  np.str_('Marcelo_Rios'): 533,
#  np.str_('Marcelo_Salas'): 534,
#  np.str_('Marco_Antonio_Barrera'): 535,
#  np.str_('Maria_Shriver'): 536,
#  np.str_('Maria_Soledad_Alvear_Valenzuela'): 537,
#  np.str_('Mariah_Carey'): 538,
#  np.str_('Mariana_Pollack'): 539,
#  np.str_('Mariangel_Ruiz_Torrealba'): 540,
#  np.str_('Marieta_Chrousala'): 541,
#  np.str_('Mark_Gottfried'): 542,
#  np.str_('Mark_Hurlbert'): 543,
#  np.str_('Mark_Philippoussis'): 544,
#  np.str_('Mark_Richt'): 545,
#  np.str_('Mark_Wahlberg'): 546,
#  np.str_('Martha_Burk'): 547,
#  np.str_('Martha_Lucia_Ramirez'): 548,
#  np.str_('Martha_Stewart'): 549,
#  np.str_('Martin_McGuinness'): 550,
#  np.str_('Martin_Scorsese'): 551,
#  np.str_('Martin_Verkerk'): 552,
#  np.str_('Martina_Hingis'): 553,
#  np.str_('Martina_McBride'): 554,
#  np.str_('Marty_Mornhinweg'): 555,
#  np.str_('Mary-Kate_Olsen'): 556,
#  np.str_('Mary_Carey'): 557,
#  np.str_('Mary_Landrieu'): 558,
#  np.str_('Mary_Steenburgen'): 559,
#  np.str_('Masum_Turker'): 560,
#  np.str_('Mathias_Reichhold'): 561,
#  np.str_('Matt_Damon'): 562,
#  np.str_('Matt_Dillon'): 563,
#  np.str_('Matt_Doherty'): 564,
#  np.str_('Matthew_Broderick'): 565,
#  np.str_('Matthew_Perry'): 566,
#  np.str_('Megan_Mullally'): 567,
#  np.str_('Megawati_Sukarnoputri'): 568,
#  np.str_('Melanie_Griffith'): 569,
#  np.str_('Meryl_Streep'): 570,
#  np.str_('Mian_Khursheed_Mehmood_Kasuri'): 571,
#  np.str_('Michael_Ballack'): 572,
#  np.str_('Michael_Bloomberg'): 573,
#  np.str_('Michael_Caine'): 574,
#  np.str_('Michael_Chang'): 575,
#  np.str_('Michael_Chiklis'): 576,
#  np.str_('Michael_Douglas'): 577,
#  np.str_('Michael_Jackson'): 578,
#  np.str_('Michael_Jordan'): 579,
#  np.str_('Michael_Moore'): 580,
#  np.str_('Michael_Phelps'): 581,
#  np.str_('Michael_Powell'): 582,
#  np.str_('Michael_Schumacher'): 583,
#  np.str_('Michael_Winterbottom'): 584,
#  np.str_('Michelle_Kwan'): 585,
#  np.str_('Michelle_Pfeiffer'): 586,
#  np.str_('Michelle_Yeoh'): 587,
#  np.str_('Mick_Jagger'): 588,
#  np.str_('Mike_Krzyzewski'): 589,
#  np.str_('Mike_Martz'): 590,
#  np.str_('Mike_Myers'): 591,
#  np.str_('Mike_Tyson'): 592,
#  np.str_('Mike_Weir'): 593,
#  np.str_('Mikhail_Kasyanov'): 594,
#  np.str_('Mikhail_Wehbe'): 595,
#  np.str_('Mikhail_Youzhny'): 596,
#  np.str_('Milo_Djukanovic'): 597,
#  np.str_('Milo_Maestrecampo'): 598,
#  np.str_('Mireya_Moscoso'): 599,
#  np.str_('Mitchell_Daniels'): 600,
#  np.str_('Mohamed_ElBaradei'): 601,
#  np.str_('Mohammad_Khatami'): 602,
#  np.str_('Mohammed_Al-Douri'): 603,
#  np.str_('Mohammed_Baqir_al-Hakim'): 604,
#  np.str_('Monica_Bellucci'): 605,
#  np.str_('Monica_Lewinsky'): 606,
#  np.str_('Monica_Seles'): 607,
#  np.str_('Monique_Garbrecht-Enfeldt'): 608,
#  np.str_('Moshe_Katsav'): 609,
#  np.str_('Muhammad_Ali'): 610,
#  np.str_('Muhammad_Saeed_al-Sahhaf'): 611,
#  np.str_('Mukesh_Ambani'): 612,
#  np.str_('Nabil_Shaath'): 613,
#  np.str_('Nadia_Petrova'): 614,
#  np.str_('Naji_Sabri'): 615,
#  np.str_('Nan_Wang'): 616,
#  np.str_('Nancy_Pelosi'): 617,
#  np.str_('Naomi_Watts'): 618,
#  np.str_('Naoto_Kan'): 619,
#  np.str_('Natalie_Cole'): 620,
#  np.str_('Natalie_Coughlin'): 621,
#  np.str_('Natalie_Maines'): 622,
#  np.str_('Natasha_McElhone'): 623,
#  np.str_('Nathalie_Baye'): 624,
#  np.str_('Nelson_Mandela'): 625,
#  np.str_('Nestor_Kirchner'): 626,
#  np.str_('Nia_Vardalos'): 627,
#  np.str_('Nicanor_Duarte_Frutos'): 628,
#  np.str_('Nick_Nolte'): 629,
#  np.str_('Nicolas_Cage'): 630,
#  np.str_('Nicole_Kidman'): 631,
#  np.str_('Noah_Wyle'): 632,
#  np.str_('Noelle_Bush'): 633,
#  np.str_('Norah_Jones'): 634,
#  np.str_('Norm_Coleman'): 635,
#  np.str_('Norodom_Sihanouk'): 636,
#  np.str_('Omar_Sharif'): 637,
#  np.str_('Oprah_Winfrey'): 638,
#  np.str_('Orlando_Bloom'): 639,
#  np.str_('Osama_bin_Laden'): 640,
#  np.str_('Oscar_De_La_Hoya'): 641,
#  np.str_('Oswaldo_Paya'): 642,
#  np.str_('Oxana_Fedorova'): 643,
#  np.str_('Ozzy_Osbourne'): 644,
#  np.str_('Padraig_Harrington'): 645,
#  np.str_('Pamela_Anderson'): 646,
#  np.str_('Paradorn_Srichaphan'): 647,
#  np.str_('Pascal_Quignard'): 648,
#  np.str_('Patricia_Clarkson'): 649,
#  np.str_('Patti_Labelle'): 650,
#  np.str_('Patty_Schnyder'): 651,
#  np.str_('Paul-Henri_Mathieu'): 652,
#  np.str_('Paul_Bremer'): 653,
#  np.str_('Paul_Burrell'): 654,
#  np.str_('Paul_Gascoigne'): 655,
#  np.str_('Paul_Martin'): 656,
#  np.str_('Paul_McCartney'): 657,
#  np.str_('Paul_ONeill'): 658,
#  np.str_('Paul_Sarbanes'): 659,
#  np.str_('Paul_Shanley'): 660,
#  np.str_('Paul_Tagliabue'): 661,
#  np.str_('Paul_Wellstone'): 662,
#  np.str_('Paul_Wolfowitz'): 663,
#  np.str_('Paula_Radcliffe'): 664,
#  np.str_('Pedro_Almodovar'): 665,
#  np.str_('Pedro_Malan'): 666,
#  np.str_('Pedro_Solbes'): 667,
#  np.str_('Penelope_Cruz'): 668,
#  np.str_('Pervez_Musharraf'): 669,
#  np.str_('Pete_Carroll'): 670,
#  np.str_('Pete_Sampras'): 671,
#  np.str_('Peter_Arnett'): 672,
#  np.str_('Peter_Struck'): 673,
#  np.str_('Petria_Thomas'): 674,
#  np.str_('Phan_Van_Khai'): 675,
#  np.str_('Pierce_Brosnan'): 676,
#  np.str_('Pierre_Pettigrew'): 677,
#  np.str_('Placido_Domingo'): 678,
#  np.str_('Prince_Charles'): 679,
#  np.str_('Prince_Claus'): 680,
#  np.str_('Prince_Harry'): 681,
#  np.str_('Prince_Naruhito'): 682,
#  np.str_('Prince_Willem-Alexander'): 683,
#  np.str_('Princess_Caroline'): 684,
#  np.str_('Pupi_Avati'): 685,
#  np.str_('Queen_Beatrix'): 686,
#  np.str_('Queen_Elizabeth_II'): 687,
#  np.str_('Queen_Latifah'): 688,
#  np.str_('Queen_Rania'): 689,
#  np.str_('Rachel_Griffiths'): 690,
#  np.str_('Rachel_Hunter'): 691,
#  np.str_('Rafael_Ramirez'): 692,
#  np.str_('Rainer_Schuettler'): 693,
#  np.str_('Ralf_Schumacher'): 694,
#  np.str_('Ranil_Wickremasinghe'): 695,
#  np.str_('Raoul_Ruiz'): 696,
#  np.str_('Ray_Allen'): 697,
#  np.str_('Ray_Romano'): 698,
#  np.str_('Rebecca_Romijn-Stamos'): 699,
#  np.str_('Rebekah_Chantay_Revels'): 700,
#  np.str_('Recep_Tayyip_Erdogan'): 701,
#  np.str_('Reese_Witherspoon'): 702,
#  np.str_('Renee_Zellweger'): 703,
#  np.str_('Ricardo_Lagos'): 704,
#  np.str_('Ricardo_Sanchez'): 705,
#  np.str_('Richard_Armitage'): 706,
#  np.str_('Richard_Gephardt'): 707,
#  np.str_('Richard_Gere'): 708,
#  np.str_('Richard_Krajicek'): 709,
#  np.str_('Richard_Myers'): 710,
#  np.str_('Richard_Virenque'): 711,
#  np.str_('Rick_Barnes'): 712,
#  np.str_('Rick_Carlisle'): 713,
#  np.str_('Rick_Dinse'): 714,
#  np.str_('Rick_Perry'): 715,
#  np.str_('Rick_Pitino'): 716,
#  np.str_('Rick_Romley'): 717,
#  np.str_('Rick_Santorum'): 718,
#  np.str_('Rick_Stansbury'): 719,
#  np.str_('Rita_Grande'): 720,
#  np.str_('Rita_Wilson'): 721,
#  np.str_('Rob_Lowe'): 722,
#  np.str_('Rob_Marshall'): 723,
#  np.str_('Robbie_Williams'): 724,
#  np.str_('Robert_Blake'): 725,
#  np.str_('Robert_Bonner'): 726,
#  np.str_('Robert_De_Niro'): 727,
#  np.str_('Robert_Duvall'): 728,
#  np.str_('Robert_Evans'): 729,
#  np.str_('Robert_Kocharian'): 730,
#  np.str_('Robert_Mueller'): 731,
#  np.str_('Robert_Redford'): 732,
#  np.str_('Robert_Torricelli'): 733,
#  np.str_('Robert_Zoellick'): 734,
#  np.str_('Roberto_Carlos'): 735,
#  np.str_('Roberto_Marinho'): 736,
#  np.str_('Rod_Stewart'): 737,
#  np.str_('Roger_Federer'): 738,
#  np.str_('Roger_Moore'): 739,
#  np.str_('Roh_Moo-hyun'): 740,
#  np.str_('Roman_Polanski'): 741,
#  np.str_('Romano_Prodi'): 742,
#  np.str_('Ron_Dittemore'): 743,
#  np.str_('Ronald_Reagan'): 744,
#  np.str_('Ronaldo_Luis_Nazario_de_Lima'): 745,
#  np.str_('Roseanne_Barr'): 746,
#  np.str_('Roy_Moore'): 747,
#  np.str_('Roy_Williams'): 748,
#  np.str_('Rubens_Barrichello'): 749,
#  np.str_('Rudolph_Giuliani'): 750,
#  np.str_('Rupert_Grint'): 751,
#  np.str_('Russell_Simmons'): 752,
#  np.str_('Sachiko_Yamada'): 753,
#  np.str_('Saddam_Hussein'): 754,
#  np.str_('Sadie_Frost'): 755,
#  np.str_('Sally_Field'): 756,
#  np.str_('Sally_Kirkland'): 757,
#  np.str_('Salma_Hayek'): 758,
#  np.str_('Salman_Rushdie'): 759,
#  np.str_('Sam_Bith'): 760,
#  np.str_('Sam_Torrance'): 761,
#  np.str_('Samuel_Waksal'): 762,
#  np.str_('Sandra_Bullock'): 763,
#  np.str_('Sarah_Hughes'): 764,
#  np.str_('Sarah_Jessica_Parker'): 765,
#  np.str_('Sarah_Michelle_Gellar'): 766,
#  np.str_('Scott_McClellan'): 767,
#  np.str_('Scott_Peterson'): 768,
#  np.str_('Sean_Astin'): 769,
#  np.str_('Sean_OKeefe'): 770,
#  np.str_('Sean_Patrick_OMalley'): 771,
#  np.str_('Sean_Penn'): 772,
#  np.str_('Sebastian_Saja'): 773,
#  np.str_('Sebastien_Grosjean'): 774,
#  np.str_('Sepp_Blatter'): 775,
#  np.str_('Serena_Williams'): 776,
#  np.str_('Sergei_Ivanov'): 777,
#  np.str_('Sergey_Lavrov'): 778,
#  np.str_('Sergio_Vieira_De_Mello'): 779,
#  np.str_('Sharon_Osbourne'): 780,
#  np.str_('Sharon_Stone'): 781,
#  np.str_('Shaul_Mofaz'): 782,
#  np.str_('Sheila_Copps'): 783,
#  np.str_('Sheryl_Crow'): 784,
#  np.str_('Shimon_Peres'): 785,
#  np.str_('Sila_Calderon'): 786,
#  np.str_('Silvan_Shalom'): 787,
#  np.str_('Silvia_Farina_Elia'): 788,
#  np.str_('Silvio_Berlusconi'): 789,
#  np.str_('Slobodan_Milosevic'): 790,
#  np.str_('Sonia_Gandhi'): 791,
#  np.str_('Sophia_Loren'): 792,
#  np.str_('Sourav_Ganguly'): 793,
#  np.str_('Spencer_Abraham'): 794,
#  np.str_('Stanley_McChrystal'): 795,
#  np.str_('Steffi_Graf'): 796,
#  np.str_('Steve_Ballmer'): 797,
#  np.str_('Steve_Lavin'): 798,
#  np.str_('Steve_Mariucci'): 799,
#  np.str_('Steve_Nash'): 800,
#  np.str_('Steven_Spielberg'): 801,
#  np.str_('Stockard_Channing'): 802,
#  np.str_('Strom_Thurmond'): 803,
#  np.str_('Susan_Sarandon'): 804,
#  np.str_('Susilo_Bambang_Yudhoyono'): 805,
#  np.str_('Sylvester_Stallone'): 806,
#  np.str_('Taha_Yassin_Ramadan'): 807,
#  np.str_('Tang_Jiaxuan'): 808,
#  np.str_('Tariq_Aziz'): 809,
#  np.str_('Tassos_Papadopoulos'): 810,
#  np.str_('Taufik_Hidayat'): 811,
#  np.str_('Terry_McAuliffe'): 812,
#  np.str_('Thabo_Mbeki'): 813,
#  np.str_('Thaksin_Shinawatra'): 814,
#  np.str_('Theodore_Tweed_Roosevelt'): 815,
#  np.str_('Theresa_May'): 816,
#  np.str_('Thierry_Falise'): 817,
#  np.str_('Thomas_Fargo'): 818,
#  np.str_('Thomas_OBrien'): 819,
#  np.str_('Thomas_Rupprath'): 820,
#  np.str_('Tiger_Woods'): 821,
#  np.str_('Tim_Allen'): 822,
#  np.str_('Tim_Conway'): 823,
#  np.str_('Tim_Duncan'): 824,
#  np.str_('Tim_Henman'): 825,
#  np.str_('Tim_Robbins'): 826,
#  np.str_('Todd_Haynes'): 827,
#  np.str_('Tom_Craddick'): 828,
#  np.str_('Tom_Crean'): 829,
#  np.str_('Tom_Cruise'): 830,
#  np.str_('Tom_Daschle'): 831,
#  np.str_('Tom_Hanks'): 832,
#  np.str_('Tom_Harkin'): 833,
#  np.str_('Tom_Reilly'): 834,
#  np.str_('Tom_Ridge'): 835,
#  np.str_('Tom_Watson'): 836,
#  np.str_('Tommy_Franks'): 837,
#  np.str_('Tommy_Haas'): 838,
#  np.str_('Tommy_Robredo'): 839,
#  np.str_('Tommy_Thompson'): 840,
#  np.str_('Toni_Braxton'): 841,
#  np.str_('Tony_Bennett'): 842,
#  np.str_('Tony_Blair'): 843,
#  np.str_('Tony_Shalhoub'): 844,
#  np.str_('Tony_Stewart'): 845,
#  np.str_('Toshihiko_Fukui'): 846,
#  np.str_('Trent_Lott'): 847,
#  np.str_('Tubby_Smith'): 848,
#  np.str_('Tung_Chee-hwa'): 849,
#  np.str_('Uma_Thurman'): 850,
#  np.str_('Vaclav_Havel'): 851,
#  np.str_('Valentino_Rossi'): 852,
#  np.str_('Valery_Giscard_dEstaing'): 853,
#  np.str_('Vanessa_Incontrada'): 854,
#  np.str_('Vanessa_Redgrave'): 855,
#  np.str_('Vanessa_Williams'): 856,
#  np.str_('Venus_Williams'): 857,
#  np.str_('Vicente_Fernandez'): 858,
#  np.str_('Vicente_Fox'): 859,
#  np.str_('Victoria_Beckham'): 860,
#  np.str_('Victoria_Clarke'): 861,
#  np.str_('Vince_Carter'): 862,
#  np.str_('Vincent_Brooks'): 863,
#  np.str_('Vincent_Gallo'): 864,
#  np.str_('Vitali_Klitschko'): 865,
#  np.str_('Vladimir_Putin'): 866,
#  np.str_('Vladimir_Spidla'): 867,
#  np.str_('Vladimiro_Montesinos'): 868,
#  np.str_('Vojislav_Kostunica'): 869,
#  np.str_('Walter_Mondale'): 870,
#  np.str_('Wang_Yingfan'): 871,
#  np.str_('Warren_Buffett'): 872,
#  np.str_('Wayne_Ferreira'): 873,
#  np.str_('Wayne_Gretzky'): 874,
#  np.str_('Wen_Jiabao'): 875,
#  np.str_('William_Bratton'): 876,
#  np.str_('William_Bulger'): 877,
#  np.str_('William_Donaldson'): 878,
#  np.str_('William_Ford_Jr'): 879,
#  np.str_('William_Macy'): 880,
#  np.str_('Win_Aung'): 881,
#  np.str_('Winona_Ryder'): 882,
#  np.str_('Wolfgang_Schuessel'): 883,
#  np.str_('Woody_Allen'): 884,
#  np.str_('Wu_Yi'): 885,
#  np.str_('Xanana_Gusmao'): 886,
#  np.str_('Xavier_Malisse'): 887,
#  np.str_('Yao_Ming'): 888,
#  np.str_('Yasar_Yakis'): 889,
#  np.str_('Yashwant_Sinha'): 890,
#  np.str_('Yasser_Arafat'): 891,
#  np.str_('Yevgeny_Kafelnikov'): 892,
#  np.str_('Yoko_Ono'): 893,
#  np.str_('Yoriko_Kawaguchi'): 894,
#  np.str_('Yu_Shyi-kun'): 895,
#  np.str_('Zhang_Ziyi'): 896,
#  np.str_('Zhu_Rongji'): 897,
#  np.str_('Zico'): 898,
#  np.str_('Zinedine_Zidane'): 899,
#  np.str_('Zoran_Djindjic'): 900}

# %%
files_db, ids_db = [], []
files_query, ids_query = [], []

for person in persons_known:
    _id = person_to_id[person]
    files = sorted(glob(os.path.join(DATA_DIR, person, '*.jpg')))

    l = len(files)
    q = int(np.ceil(l * DB_RATIO))

    files_db.extend(files[:q])
    ids_db.extend([_id] * q)

    files_query.extend(files[q:])
    ids_query.extend([_id] * (l - q))

for person in persons_unkonwn:
    files = sorted(glob(os.path.join(DATA_DIR, person, '*.jpg')))

    files_query.extend(files)
    ids_query.extend([np.nan] * len(files))

files_db = np.asarray(files_db)
ids_db = np.asarray(ids_db)

files_query = np.asarray(files_query)
ids_query = np.asarray(ids_query)

print(files_db.size, ids_db.size)
print(files_query.size, ids_query.size)
# Out:
# 1823 1823
# 11410 11410

# %% [markdown]
# # 1st-level predictor

# %%
# %cd /content/drive/MyDrive/dl_for_cv/
# Out:
# /content/drive/MyDrive/dl_for_cv

# %% [markdown]
# Our 1st-level predictor (aka embedding generator). Essentially this is ResNet-50 slighlty modified for REID heads. See [origin](https://github.com/TreB1eN/InsightFace_Pytorch) and big thanks authors for their work!

# %%
FACE_SIZE = 112

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# %% [markdown]
# *Model definition from [this file](https://github.com/TreB1eN/InsightFace_Pytorch/blob/master/model.py).*

# %%
from torch.nn import Linear, Conv2d, BatchNorm1d, BatchNorm2d, PReLU, ReLU, Sigmoid, Dropout, MaxPool2d, AdaptiveAvgPool2d, Sequential, Module
from collections import namedtuple

class Flatten(Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

def l2_norm(input,axis=1):
    norm = torch.norm(input,2,axis,True)
    output = torch.div(input, norm)
    return output

class SEModule(Module):
    def __init__(self, channels, reduction):
        super(SEModule, self).__init__()
        self.avg_pool = AdaptiveAvgPool2d(1)
        self.fc1 = Conv2d(
            channels, channels // reduction, kernel_size=1, padding=0 ,bias=False)
        self.relu = ReLU(inplace=True)
        self.fc2 = Conv2d(
            channels // reduction, channels, kernel_size=1, padding=0 ,bias=False)
        self.sigmoid = Sigmoid()

    def forward(self, x):
        module_input = x
        x = self.avg_pool(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return module_input * x

class bottleneck_IR(Module):
    def __init__(self, in_channel, depth, stride):
        super(bottleneck_IR, self).__init__()
        if in_channel == depth:
            self.shortcut_layer = MaxPool2d(1, stride)
        else:
            self.shortcut_layer = Sequential(
                Conv2d(in_channel, depth, (1, 1), stride ,bias=False), BatchNorm2d(depth))
        self.res_layer = Sequential(
            BatchNorm2d(in_channel),
            Conv2d(in_channel, depth, (3, 3), (1, 1), 1 ,bias=False), PReLU(depth),
            Conv2d(depth, depth, (3, 3), stride, 1 ,bias=False), BatchNorm2d(depth))

    def forward(self, x):
        shortcut = self.shortcut_layer(x)
        res = self.res_layer(x)
        return res + shortcut

class bottleneck_IR_SE(Module):
    def __init__(self, in_channel, depth, stride):
        super(bottleneck_IR_SE, self).__init__()
        if in_channel == depth:
            self.shortcut_layer = MaxPool2d(1, stride)
        else:
            self.shortcut_layer = Sequential(
                Conv2d(in_channel, depth, (1, 1), stride ,bias=False),
                BatchNorm2d(depth))
        self.res_layer = Sequential(
            BatchNorm2d(in_channel),
            Conv2d(in_channel, depth, (3,3), (1,1),1 ,bias=False),
            PReLU(depth),
            Conv2d(depth, depth, (3,3), stride, 1 ,bias=False),
            BatchNorm2d(depth),
            SEModule(depth,16)
            )
    def forward(self,x):
        shortcut = self.shortcut_layer(x)
        res = self.res_layer(x)
        return res + shortcut

class Bottleneck(namedtuple('Block', ['in_channel', 'depth', 'stride'])):
    '''A named tuple describing a ResNet block.'''

def get_block(in_channel, depth, num_units, stride = 2):
  return [Bottleneck(in_channel, depth, stride)] + [Bottleneck(depth, depth, 1) for i in range(num_units-1)]

def get_blocks(num_layers):
    if num_layers == 50:
        blocks = [
            get_block(in_channel=64, depth=64, num_units = 3),
            get_block(in_channel=64, depth=128, num_units=4),
            get_block(in_channel=128, depth=256, num_units=14),
            get_block(in_channel=256, depth=512, num_units=3)
        ]
    elif num_layers == 100:
        blocks = [
            get_block(in_channel=64, depth=64, num_units=3),
            get_block(in_channel=64, depth=128, num_units=13),
            get_block(in_channel=128, depth=256, num_units=30),
            get_block(in_channel=256, depth=512, num_units=3)
        ]
    elif num_layers == 152:
        blocks = [
            get_block(in_channel=64, depth=64, num_units=3),
            get_block(in_channel=64, depth=128, num_units=8),
            get_block(in_channel=128, depth=256, num_units=36),
            get_block(in_channel=256, depth=512, num_units=3)
        ]
    return blocks

class Backbone(Module):
    def __init__(self, num_layers, drop_ratio, mode='ir'):
        super(Backbone, self).__init__()
        assert num_layers in [50, 100, 152], 'num_layers should be 50,100, or 152'
        assert mode in ['ir', 'ir_se'], 'mode should be ir or ir_se'
        blocks = get_blocks(num_layers)
        if mode == 'ir':
            unit_module = bottleneck_IR
        elif mode == 'ir_se':
            unit_module = bottleneck_IR_SE
        self.input_layer = Sequential(Conv2d(3, 64, (3, 3), 1, 1 ,bias=False),
                                      BatchNorm2d(64),
                                      PReLU(64))
        self.output_layer = Sequential(BatchNorm2d(512),
                                       Dropout(drop_ratio),
                                       Flatten(),
                                       Linear(512 * 7 * 7, 512),
                                       BatchNorm1d(512))
        modules = []
        for block in blocks:
            for bottleneck in block:
                modules.append(
                    unit_module(bottleneck.in_channel,
                                bottleneck.depth,
                                bottleneck.stride))
        self.body = Sequential(*modules)

    def forward(self,x):
        x = self.input_layer(x)
        x = self.body(x)
        x = self.output_layer(x)
        return l2_norm(x)

# %% [markdown]
# Model weights are from [here](https://github.com/TreB1eN/InsightFace_Pytorch#32-detect-over-camera). **Please download it manually**.

# %%
model = Backbone(50, 0.0, mode='ir_se').eval()
model.load_state_dict(torch.load('model_ir_se50.pth'))
model.cuda()
# Out:
# Backbone(
#   (input_layer): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): PReLU(num_parameters=64)
#   )
#   (output_layer): Sequential(
#     (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Dropout(p=0.0, inplace=False)
#     (2): Flatten()
#     (3): Linear(in_features=25088, out_features=512, bias=True)
#     (4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (body): Sequential(
#     (0): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=64)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=64)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (2): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=64)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (3): bottleneck_IR_SE(
#       (shortcut_layer): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (res_layer): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=128)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (4): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=128)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (5): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=128)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (6): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=128)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (7): bottleneck_IR_SE(
#       (shortcut_layer): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (res_layer): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (8): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (9): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (10): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (11): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (12): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (13): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (14): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (15): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (16): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (17): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (18): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (19): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (20): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=256)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (21): bottleneck_IR_SE(
#       (shortcut_layer): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (res_layer): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=512)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (22): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=512)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (23): bottleneck_IR_SE(
#       (shortcut_layer): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       (res_layer): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): PReLU(num_parameters=512)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# *This one is not related to the repo..*

# %%
def gen_embds(fs):
    embds = []
    for f in tqdm(fs):
        img = dlib.load_rgb_image(f)

        dets = face_detector(img)
        if len(dets) == 0:
            embds.append(np.zeros((512,)))
            continue

        landmarks = shape_predictor(img, dets[0])
        face_crop = dlib.get_face_chip(img, landmarks, size=FACE_SIZE, padding=0.3)[:, :, [2, 1, 0]]

        with torch.no_grad():
            embd = model(transform(face_crop).unsqueeze(0).cuda())[0]
        embds.append(embd.cpu().numpy())

    return np.asarray(embds)

# %% [markdown]
# See [this](http://dlib.net/face_detector.py.html) cookbook for `dlib` face detection or [this one](http://dlib.net/face_alignment.py.html) for face alignment.

# %%
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !bunzip2 shape_predictor_5_face_landmarks.dat.bz2
# Out:
# --2025-05-10 08:25:06--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2 [following]
# --2025-05-10 08:25:06--  https://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Connecting to dlib.net (dlib.net)|107.180.26.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2’
#
# shape_predictor_5_f 100%[===================>]   5.44M  8.54MB/s    in 0.6s
#
# 2025-05-10 08:25:07 (8.54 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2’ saved [5706710/5706710]
#
# bunzip2: Output file shape_predictor_5_face_landmarks.dat already exists.

# %%
face_detector = dlib.get_frontal_face_detector()
shape_predictor = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')

# %% [markdown]
# Let's detect faces and generate embeddings:

# %%
embds_db = gen_embds(files_db)
embds_query = gen_embds(files_query)

print(embds_db.shape, ids_db.shape)
print(embds_query.shape, ids_query.shape)
# Out:
#   0%|          | 0/1823 [00:00<?, ?it/s]
#   0%|          | 0/11410 [00:00<?, ?it/s]
# (1823, 512) (1823,)
# (11410, 512) (11410,)

# %%
inds = np.abs(embds_db).sum(axis=1) > 0

embds_db = embds_db[inds]
ids_db = ids_db[inds]

print(embds_db.shape, ids_db.shape)
# Out:
# (1818, 512) (1818,)

# %%
inds = np.abs(embds_query).sum(axis=1) > 0

embds_query = embds_query[inds]
ids_query = ids_query[inds]

print(embds_query.shape, ids_query.shape)
# Out:
# (11357, 512) (11357,)

# %% [markdown]
# Just sanity check:

# %%
print(np.unique(ids_db).size, ids_db.max())
assert np.unique(ids_db).size == ids_db.max() - 1
# Out:
# 899 900

# %% [markdown]
# Save embeddings in the appropriate format for the further analysis in the Embedding Projector:

# %%
f_data = open('arface_lfw.tsv', 'w')

for embd in embds_db:
    f_data.write('\t'.join([str(round(v, 4)) for v in embd]) + '\n')

f_data.flush()
f_data.close()

# %%
f_meta = open('arface_lfw_meta.tsv', 'w')

for _id in ids_db:
    f_meta.write('person{}\n'.format(int(_id)))

f_meta.flush()
f_meta.close()

# %% [markdown]
# Store embeddings itself in order not to process the dataset every time:

# %%
np.save(os.path.join(DATA_DIR, 'embds_db'), embds_db)
np.save(os.path.join(DATA_DIR, 'ids_db'), ids_db)

# %%
np.save(os.path.join(DATA_DIR, 'embds_query'), embds_query)
np.save(os.path.join(DATA_DIR, 'ids_query'), ids_query)

# %% [markdown]
# # 2nd-level predictor

# %%
def cosine_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def cosine_dist(v1, v2):
    return 1 - cosine_sim(v1, v2)

# %%
def euc_dist(v1, v2):
    return np.linalg.norm(v1 - v2)

# %% [markdown]
# *(you can find them into numpy / scipy / sklearn etc)*

# %%
embds_db = np.load(os.path.join(DATA_DIR, 'embds_db.npy'))
ids_db = np.load(os.path.join(DATA_DIR, 'ids_db.npy'))

print(embds_db.shape, ids_db.shape)
# Out:
# (1818, 512) (1818,)

# %%
embds_query = np.load(os.path.join(DATA_DIR, 'embds_query.npy'))
ids_query = np.load(os.path.join(DATA_DIR, 'ids_query.npy'))

print(embds_query.shape, ids_query.shape)
# Out:
# (11357, 512) (11357,)

# %%
search_params = {
    'n_neighbors': [1, 3, 5],
    'weights': ['uniform', 'distance'],
    'metric': ['minkowski', cosine_dist]
}
predictor = knn.KNeighborsClassifier(n_jobs=-1)
classifier = GridSearchCV(predictor, search_params, n_jobs=-1, verbose=3)

# %%
classifier.fit(embds_db, ids_db)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# GridSearchCV(estimator=KNeighborsClassifier(n_jobs=-1), n_jobs=-1,
#              param_grid={'metric': ['minkowski',
#                                     <function cosine_dist at 0x7fc5f4b57380>],
#                          'n_neighbors': [1, 3, 5],
#                          'weights': ['uniform', 'distance']},
#              verbose=3)

# %%
float(classifier.best_score_)
# Out:
# 0.5874685920140467

# %%
classifier.best_params_
# Out:
# {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}

# %%
df = pd.DataFrame.from_dict(classifier.cv_results_)

print(df.shape)
# Out:
# (12, 16)

# %%
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006136      0.000154         0.053160        0.023793
# 1        0.003393      0.000200         0.040123        0.001246
# 2        0.003521      0.000210         0.035506        0.001129
# 3        0.003349      0.000302         0.049615        0.002878
# 4        0.005977      0.002547         0.044211        0.010488
# 5        0.007734      0.006178         0.072607        0.035306
# 6        0.005701      0.003445         8.839343        0.383487
# 7        0.005124      0.001687         9.114845        1.229031
# 8        0.005110      0.002381         8.402302        0.753761
# 9        0.003439      0.000344         8.294240        0.683282
# 10       0.006461      0.003026         8.778350        0.262472
# 11       0.003354      0.000090         8.820395        0.419569
#
#                                 param_metric  param_n_neighbors param_weights  \
# 0                                  minkowski                  1       uniform
# 1                                  minkowski                  1      distance
# 2                                  minkowski                  3       uniform
# 3                                  minkowski                  3      distance
# 4                                  minkowski                  5       uniform
# 5                                  minkowski                  5      distance
# 6   <function cosine_dist at 0x7fc5f4b57380>                  1       uniform
# 7   <function cosine_dist at 0x7fc5f4b57380>                  1      distance
# 8   <function cosine_dist at 0x7fc5f4b57380>                  3       uniform
# 9   <function cosine_dist at 0x7fc5f4b57380>                  3      distance
# 10  <function cosine_dist at 0x7fc5f4b57380>                  5       uniform
# 11  <function cosine_dist at 0x7fc5f4b57380>                  5      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'minkowski', 'n_neighbors': 1, 'wei...           0.574176
# 1   {'metric': 'minkowski', 'n_neighbors': 1, 'wei...           0.574176
# 2   {'metric': 'minkowski', 'n_neighbors': 3, 'wei...           0.472527
# 3   {'metric': 'minkowski', 'n_neighbors': 3, 'wei...           0.565934
# 4   {'metric': 'minkowski', 'n_neighbors': 5, 'wei...           0.436813
# 5   {'metric': 'minkowski', 'n_neighbors': 5, 'wei...           0.524725
# 6   {'metric': <function cosine_dist at 0x7fc5f4b5...           0.574176
# 7   {'metric': <function cosine_dist at 0x7fc5f4b5...           0.574176
# 8   {'metric': <function cosine_dist at 0x7fc5f4b5...           0.472527
# 9   {'metric': <function cosine_dist at 0x7fc5f4b5...           0.565934
# 10  {'metric': <function cosine_dist at 0x7fc5f4b5...           0.436813
# 11  {'metric': <function cosine_dist at 0x7fc5f4b5...           0.527473
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.587912           0.582418           0.611570
# 1            0.587912           0.582418           0.611570
# 2            0.469780           0.478022           0.476584
# 3            0.582418           0.560440           0.600551
# 4            0.447802           0.445055           0.449036
# 5            0.554945           0.535714           0.578512
# 6            0.587912           0.582418           0.611570
# 7            0.587912           0.582418           0.611570
# 8            0.469780           0.478022           0.476584
# 9            0.582418           0.560440           0.600551
# 10           0.447802           0.445055           0.449036
# 11           0.554945           0.535714           0.578512
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.581267         0.587469        0.012820                1
# 1            0.581267         0.587469        0.012820                1
# 2            0.468320         0.473047        0.003756                9
# 3            0.570248         0.575918        0.014286                6
# 4            0.438017         0.443345        0.005025               11
# 5            0.539945         0.546768        0.018597                8
# 6            0.581267         0.587469        0.012820                1
# 7            0.581267         0.587469        0.012820                1
# 8            0.468320         0.473047        0.003756                9
# 9            0.573003         0.576469        0.014109                5
# 10           0.438017         0.443345        0.005025               11
# 11           0.542700         0.547869        0.017774                7

# %%
for i_p, p in enumerate(classifier.cv_results_['params']):
    print('{}: {}'.format(i_p, p))
# Out:
# 0: {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'uniform'}
# 1: {'metric': 'minkowski', 'n_neighbors': 1, 'weights': 'distance'}
# 2: {'metric': 'minkowski', 'n_neighbors': 3, 'weights': 'uniform'}
# 3: {'metric': 'minkowski', 'n_neighbors': 3, 'weights': 'distance'}
# 4: {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'uniform'}
# 5: {'metric': 'minkowski', 'n_neighbors': 5, 'weights': 'distance'}
# 6: {'metric': <function cosine_dist at 0x7fc5f4b57380>, 'n_neighbors': 1, 'weights': 'uniform'}
# 7: {'metric': <function cosine_dist at 0x7fc5f4b57380>, 'n_neighbors': 1, 'weights': 'distance'}
# 8: {'metric': <function cosine_dist at 0x7fc5f4b57380>, 'n_neighbors': 3, 'weights': 'uniform'}
# 9: {'metric': <function cosine_dist at 0x7fc5f4b57380>, 'n_neighbors': 3, 'weights': 'distance'}
# 10: {'metric': <function cosine_dist at 0x7fc5f4b57380>, 'n_neighbors': 5, 'weights': 'uniform'}
# 11: {'metric': <function cosine_dist at 0x7fc5f4b57380>, 'n_neighbors': 5, 'weights': 'distance'}

# %%
dist_f = cosine_dist

# %%
classifier = knn.KNeighborsClassifier(n_neighbors=1, metric=dist_f, n_jobs=-1)
classifier.fit(embds_db, ids_db)
# Out:
# KNeighborsClassifier(metric=<function cosine_dist at 0x7fc5f4b57380>, n_jobs=-1,
#                      n_neighbors=1)

# %%
with parallel_backend('threading', n_jobs=-1):
  ids_pred = classifier.predict(embds_query)

print(ids_pred.shape)
# Out:
# (11357,)

# %%
idx_known = ~np.isnan(ids_query)
idx_unknown = np.isnan(ids_query)

# %%
print(balanced_accuracy_score(ids_query[idx_known], ids_pred[idx_known]))
# Out:
# 0.725058065693951

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Prerequisites

# %%
def plot_hists(dists_pos, dists_other, dists_neg, nbins=100):
    plt.figure(figsize=(15, 5))

    plt.hist(dists_pos, color='r', bins=nbins, alpha=0.5, label='positive')
    plt.hist(dists_other, color='g', bins=nbins, alpha=0.5, label='other')
    plt.hist(dists_neg, color='b', bins=nbins, alpha=0.5, label='negative')

    plt.legend(fontsize=14)
    plt.grid(True)

# %%
def plot_far_frr(xs, ys, thrs):
    plt.figure(figsize=(15, 5))

    plt.plot(xs, ys, 'r')
    plt.grid(True)

    for x, y in zip(xs, ys):
        plt.stem([x], [y], 'k--')
    for i, thr in enumerate(thrs):
        plt.text(
            xs[i], ys[i] + 0.01, str(round(thr, 2)),
            horizontalalignment='center', verticalalignment='bottom', fontsize=14, fontweight='bold'
    )

    plt.xlabel('FAR', fontsize=18)
    plt.ylabel('FRR', fontsize=18)

    plt.tick_params(labelsize=14)

# %%
def plot_thresholds(xs, ys, thrs):
    plt.figure(figsize=(15, 5))

    plt.plot(thrs, xs, 'b', label='FAR', linewidth=2.0)
    plt.plot(thrs, ys, 'g', label='FRR', linewidth=2.0)
    plt.grid(True)

    plt.xlabel('threshold (distance)', fontsize=18)
    plt.ylabel('rate', fontsize=18)

    plt.legend(fontsize=14)
    plt.tick_params(labelsize=14)

# %% [markdown]
# ## Embedding analysis

# %%
dmtx_db_query = np.empty((len(ids_db), len(ids_query)))

for i_db, embd_db in enumerate(tqdm(embds_db)):
    for i_query, embd_query in enumerate(embds_query):
        dmtx_db_query[i_db, i_query] = dist_f(embd_db, embd_query)

print(dmtx_db_query.shape)
# Out:
#   0%|          | 0/1818 [00:00<?, ?it/s]
# (1818, 11357)

# %%
idx_pred = dmtx_db_query.argmin(0)
ids_pred_ = np.asarray([ids_db[_id] for _id in idx_pred])

# %%
float((ids_pred[idx_known] - ids_pred_[idx_known]).sum())
# Out:
# 0.0

# %%
dists_pos, dists_other, dists_neg = [], [], []

for c in tqdm(np.unique(ids_db)):
    embds_pos = embds_query[ids_query == c]
    idx = np.arange(len(embds_pos))
    for id1, id2 in itertools.combinations(idx, 2):
        dist = dist_f(embds_pos[id1], embds_pos[id2])
        dists_pos.append(dist)

    embds_other = embds_query[(idx_known) & (ids_query != c)]
    for embd_pos in embds_pos:
        for embd_other in embds_other:
            dist = dist_f(embd_pos, embd_other)
            dists_other.append(dist)

dists_neg = dmtx_db_query[:, idx_unknown].flatten()

print(len(dists_pos), len(dists_other), len(dists_neg))
# Out:
#   0%|          | 0/899 [00:00<?, ?it/s]
# 151597 32822584 10178982

# %%
np.random.shuffle(dists_pos)
np.random.shuffle(dists_other)
np.random.shuffle(dists_neg)

# %%
min_q = min(len(dists_pos), len(dists_other), len(dists_neg))

# %%
plot_hists(dists_pos[:min_q], dists_other[:min_q], dists_neg[:min_q], nbins=100)
plt.stem([0.6], [6000], 'r--')
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ## FAR/FRR

# %%
thrs = np.linspace(0.3, 0.8, 11)

# %%
thrs
# Out:
# array([0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 ])

# %%
fars, frrs = [], []

dsts_pred = dmtx_db_query.min(0)
print(dsts_pred.shape)

for thr in tqdm(thrs):
    far = (dsts_pred[idx_unknown] <= thr).sum() / len(ids_query)
    fars.append(far)

    frr = (dsts_pred[idx_known] > thr).sum() / len(ids_query)
    frrs.append(frr)

#     break

fars = np.asarray(fars)
frrs = np.asarray(frrs)

print(fars.shape, frrs.shape)
# Out:
# (11357,)
#   0%|          | 0/11 [00:00<?, ?it/s]
# (11,) (11,)

# %%
fars
# Out:
# array([0.00088051, 0.00651581, 0.04807608, 0.18658096, 0.35326231,
#        0.45610637, 0.48666021, 0.49203135, 0.49273576, 0.49299991,
#        0.49299991])

# %%
frrs
# Out:
# array([2.95940829e-01, 2.07096945e-01, 1.32869596e-01, 6.70951836e-02,
#        2.44782953e-02, 5.81139385e-03, 1.05661706e-03, 1.76102844e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
plot_far_frr(fars, frrs, thrs)

# %%
plot_thresholds(fars, frrs, thrs)
